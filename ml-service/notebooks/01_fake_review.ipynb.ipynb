# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("../datasets/fake_reviews/fake_reviews.csv")

# %%
df.head()
df.shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40432 entries, 0 to 40431
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   category  40432 non-null  object
#  1   rating    40432 non-null  float64
#  2   label     40432 non-null  object
#  3   text_     40432 non-null  object
# dtypes: float64(1), object(3)
# memory usage: 1.2+ MB

# %%
df.isnull().sum()
# Out:
# category    0
# rating      0
# label       0
# text_       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(12)

# %%
df["label"].value_counts()
# Out:
# label
# CG    20216
# OR    20216
# Name: count, dtype: int64

# %%
df.sample(5)
# Out:
#                            category  rating label  \
# 33376              Toys_and_Games_5     5.0    OR
# 6159          Sports_and_Outdoors_5     1.0    OR
# 37937  Clothing_Shoes_and_Jewelry_5     4.0    OR
# 20885                Pet_Supplies_5     1.0    OR
# 2320             Home_and_Kitchen_5     2.0    OR
#
#                                                    text_
# 33376  My 5 year old grandson loves these.  He uses t...
# 6159   I think I bought fake shoes. The insole is rub...
# 37937  Wife seems to like them, and they seem to be h...
# 20885  My cat hates this thing, cheaply constructed V...
# 2320   Smells good but no foam.  I put it in three di...
